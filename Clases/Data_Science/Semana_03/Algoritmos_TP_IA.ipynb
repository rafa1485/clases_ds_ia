# %%
# Out:
# ...
#  TRAZA DE EJECUCIÓN - UCS
# ...
# Frontera actual (Prioridad, Estado): [(0, 'S')]
# -> Extrayendo nodo: S (Prioridad: 0, g=0, h=7)
# Frontera actual (Prioridad, Estado): [(2, 'A'), (2, 'B')]
# -> Extrayendo nodo: A (Prioridad: 2, g=2, h=5)
# Frontera actual (Prioridad, Estado): [(2, 'B'), (4, 'C'), (7, 'D')]
# -> Extrayendo nodo: B (Prioridad: 2, g=2, h=8)
# Frontera actual (Prioridad, Estado): [(4, 'C'), (7, 'D'), (4, 'D')]
# -> Extrayendo nodo: C (Prioridad: 4, g=4, h=3)
# Frontera actual (Prioridad, Estado): [(4, 'D'), (7, 'D'), (7, 'G')]
# -> Extrayendo nodo: D (Prioridad: 4, g=4, h=6)
# Frontera actual (Prioridad, Estado): [(7, 'D'), (7, 'G')]
# -> Descartado (obsoleto): D con g=7
# Frontera actual (Prioridad, Estado): [(7, 'G')]
# -> Extrayendo nodo: G (Prioridad: 7, g=7, h=0)
#
# ...
#  TRAZA DE EJECUCIÓN - Voraz
# ...
# Frontera actual (Prioridad, Estado): [(7, 'S')]
# -> Extrayendo nodo: S (Prioridad: 7, g=0, h=7)
# Frontera actual (Prioridad, Estado): [(5, 'A'), (8, 'B')]
# ...
